# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: python-dotenv in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: langchain in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 2)) (0.2.16)
# Requirement already satisfied: langchain_core in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 3)) (0.2.38)
# Requirement already satisfied: langchain-community in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 4)) (0.2.16)
# Requirement already satisfied: langchain-chroma in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 5)) (0.1.3)
# Requirement already satisfied: ipywidgets in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 6)) (8.1.5)
# Requirement already satisfied: umap in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: pandas in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from -r requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (3.10.5)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (0.1.116)
# Requirement already satisfied: numpy<2,>=1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain->-r requirements.txt (line 2)) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain_core->-r requirements.txt (line 3)) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain_core->-r requirements.txt (line 3)) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain_core->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain-community->-r requirements.txt (line 4)) (0.6.7)
# Requirement already satisfied: chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain-chroma->-r requirements.txt (line 5)) (0.5.3)
# Requirement already satisfied: fastapi<1,>=0.95.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from langchain-chroma->-r requirements.txt (line 5)) (0.112.2)
# Requirement already satisfied: comm>=0.1.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->-r requirements.txt (line 6)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->-r requirements.txt (line 6)) (8.27.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->-r requirements.txt (line 6)) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->-r requirements.txt (line 6)) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipywidgets->-r requirements.txt (line 6)) (3.0.13)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pandas->-r requirements.txt (line 8)) (2024.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain->-r requirements.txt (line 2)) (1.9.5)
# Requirement already satisfied: build>=1.0.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.2.1)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.7.3)
# Requirement already satisfied: uvicorn>=0.18.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.30.6)
# Requirement already satisfied: posthog>=2.4.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.6.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.19.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.27.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.48b0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.27.0)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.19.1)
# Requirement already satisfied: pypika>=0.48.9 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (4.66.5)
# Requirement already satisfied: overrides>=7.3.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (7.7.0)
# Requirement already satisfied: importlib-resources in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (6.4.4)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.66.1)
# Requirement already satisfied: bcrypt>=4.0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (4.2.0)
# Requirement already satisfied: typer>=0.9.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.12.5)
# Requirement already satisfied: kubernetes>=28.1.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (30.1.0)
# Requirement already satisfied: mmh3>=4.0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (4.1.0)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.10.7)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.27.2)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (0.9.0)
# Requirement already satisfied: starlette<0.39.0,>=0.37.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from fastapi<1,>=0.95.2->langchain-chroma->-r requirements.txt (line 5)) (0.38.2)
# Requirement already satisfied: decorator in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.19.1)
# Requirement already satisfied: matplotlib-inline in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.1.7)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (3.0.47)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (2.18.0)
# Requirement already satisfied: stack-data in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.6.3)
# Requirement already satisfied: colorama in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.4.6)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core->-r requirements.txt (line 3)) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 2)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pydantic<3,>=1->langchain->-r requirements.txt (line 2)) (2.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r requirements.txt (line 8)) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from requests<3,>=2->langchain->-r requirements.txt (line 2)) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: pyproject_hooks in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from build>=1.0.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.1.0)
# Requirement already satisfied: anyio in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: httpcore==1.* in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.0.5)
# Requirement already satisfied: sniffio in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.8.4)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (2.34.0)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.8.0)
# Requirement already satisfied: requests-oauthlib in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: oauthlib>=3.2.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.2.2)
# Requirement already satisfied: coloredlogs in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (15.0.1)
# Requirement already satisfied: flatbuffers in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (24.3.25)
# Requirement already satisfied: protobuf in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (4.25.4)
# Requirement already satisfied: sympy in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.13.2)
# Requirement already satisfied: deprecated>=1.2.6 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.2.14)
# Requirement already satisfied: importlib-metadata<=8.4.0,>=6.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (8.4.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.65.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.27.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.27.0)
# Requirement already satisfied: opentelemetry-proto==1.27.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.27.0)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.48b0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.48b0)
# Requirement already satisfied: opentelemetry-instrumentation==0.48b0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.48b0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.48b0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.48b0)
# Requirement already satisfied: opentelemetry-util-http==0.48b0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.48b0)
# Requirement already satisfied: setuptools>=16.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (65.5.0)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.16.0)
# Requirement already satisfied: asgiref~=3.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from opentelemetry-instrumentation-asgi==0.48b0->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from posthog>=2.4.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (2.2.1)
# Requirement already satisfied: wcwidth in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.2.13)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.24.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (13.8.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: httptools>=0.5.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: watchfiles>=0.13 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.24.0)
# Requirement already satisfied: websockets>=10.4 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (13.0.1)
# Requirement already satisfied: executing>=1.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (2.4.1)
# Requirement already satisfied: pure-eval in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets->-r requirements.txt (line 6)) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (4.9)
# Requirement already satisfied: filelock in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (2024.6.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from importlib-metadata<=8.4.0,>=6.0->opentelemetry-api>=1.2.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.20.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (1.3.0)
# Requirement already satisfied: pyreadline3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer>=0.9.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb!=0.5.4,!=0.5.5,<0.6.0,>=0.4.0->langchain-chroma->-r requirements.txt (line 5)) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipywidgets as widgets
from IPython.display import display, clear_output, HTML
import chromadb
from chromadb.config import DEFAULT_TENANT, DEFAULT_DATABASE, Settings
from langchain_chroma import Chroma
#from langchain_openai import OpenAIEmbeddings
import os
import pandas as pd
import random
from dotenv import load_dotenv

# Load configuration settings from the .env file
load_dotenv()

CHROMA_DB_PATH = os.getenv('CHROMA_DB_PATH')

# Set up chromadb client
client = chromadb.PersistentClient(
    path=CHROMA_DB_PATH,
    settings=Settings(),
    tenant=DEFAULT_TENANT,
    database=DEFAULT_DATABASE,
)

# Function to list collections
def list_collections():
    collections = client.list_collections()
    return [collection.name for collection in collections]

# Function to display collection details
def show_details(collection_name):
    try:
        collection = client.get_collection(collection_name)
        details_output.clear_output()
        with details_output:
            print(f"Collection Name: {collection_name}")
            print(f"Document Count: {collection.count()}")
            if collection.metadata:
                for key, value in collection.metadata.items():
                    print(f"{key}: {value}")
            else:
                print("No metadata available.")
            
            # Display details of the documents in the collection
            raw_data = collection.get(limit=5)
            print("Raw Document Data:", raw_data)  # Print out raw data for inspection
            
            # Extract and display relevant data
            ids = raw_data.get('ids', [])
            metadatas = raw_data.get('metadatas', [])

            if not ids or not metadatas:
                print("No documents available or missing data.")
                return

            # Create table with clickable IDs
            table_html = "<table><tr><th>ID</th><th>Metadata</th></tr>"
            for doc_id, metadata in zip(ids, metadatas):
                table_html += f"<tr><td><a href='#' onclick='IPython.notebook.kernel.execute(\"show_document_details('{collection_name}', '{doc_id}')\")'>{doc_id}</a></td>"
                table_html += f"<td>{metadata}</td></tr>"
            table_html += "</table>"
            
            display(HTML(table_html))
    except Exception as e:
        details_output.clear_output()
        with details_output:
            print(f"Error while fetching details for collection '{collection_name}': {str(e)}")

# Function to display individual document details
def show_document_details(collection_name, doc_id):
    try:
        collection = client.get_collection(collection_name)
        document_details_output.clear_output()
        with document_details_output:
            print(f"Collection: {collection_name}, Document ID: {doc_id}")
            
            # Retrieve document details
            raw_data = collection.get(ids=[doc_id])
            if not raw_data or not raw_data.get('metadatas'):
                print(f"No details available for document ID: {doc_id}")
                return

            # Assuming getting first (and only one) document metadata and embeddings
            metadata = raw_data['metadatas'][0]
            print("Metadata:", metadata)
    except Exception as e:
        document_details_output.clear_output()
        with document_details_output:
            print(f"Error while fetching details for document ID '{doc_id}': {str(e)}")


# Function to delete collection
def delete_collection(collection_name):
    try:
        client.delete_collection(collection_name)
        refresh_collections()
    except Exception as e:
        error_output.clear_output()
        with error_output:
            print(f"Error while deleting collection '{collection_name}': {str(e)}")

# Function to refresh the list of collections
def refresh_collections():
    collection_names = list_collections()
    collection_buttons.children = [
        widgets.HBox([
            widgets.Label(value=collection_name, layout=widgets.Layout(width='200px')),
            widgets.Button(description="Delete", button_style='danger', layout=widgets.Layout(width='100px')),
            widgets.Button(description="Details", button_style='info', layout=widgets.Layout(width='100px'))
        ])
        for collection_name in collection_names
    ]
    for box in collection_buttons.children:
        name_label, delete_button, details_button = box.children
        
        # Use default arguments in lambda to capture the current collection name
        delete_button.on_click(lambda b, name=name_label.value: delete_collection(name))
        details_button.on_click(lambda b, name=name_label.value: show_details(name))

# Set up widgets
details_output = widgets.Output()
document_details_output = widgets.Output()
error_output = widgets.Output()
collection_buttons = widgets.VBox()
refresh_button = widgets.Button(description="Refresh Collections", button_style='primary')
refresh_button.on_click(lambda b: refresh_collections())

# Display widgets in the Jupyter notebook
display(refresh_button, collection_buttons, details_output, document_details_output, error_output)

# Initialize the list of collections
refresh_collections()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 18
#      15 CHROMA_DB_PATH = os.getenv('CHROMA_DB_PATH')
#      17 # Set up chromadb client
# ---> 18 client = chromadb.PersistentClient(
#      19     path=CHROMA_DB_PATH,
#      20     settings=Settings(),
#      21     tenant=DEFAULT_TENANT,
#      22     database=DEFAULT_DATABASE,
#      23 )
#      25 # Function to list collections
#      26 def list_collections():
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\__init__.py:153, in PersistentClient(path, settings, tenant, database)
#     150 tenant = str(tenant)
#     151 database = str(database)
# --> 153 return ClientCreator(tenant=tenant, database=database, settings=settings)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\client.py:55, in Client.__init__(self, tenant, database, settings)
#      49 def __init__(
#      50     self,
#      51     tenant: str = DEFAULT_TENANT,
#      52     database: str = DEFAULT_DATABASE,
#      53     settings: Settings = Settings(),
#      54 ) -> None:
# ---> 55     super().__init__(settings=settings)
#      56     self.tenant = tenant
#      57     self.database = database
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\shared_system_client.py:19, in SharedSystemClient.__init__(self, settings)
#      14 def __init__(
#      15     self,
#      16     settings: Settings = Settings(),
#      17 ) -> None:
#      18     self._identifier = SharedSystemClient._get_identifier_from_settings(settings)
# ---> 19     SharedSystemClient._create_system_if_not_exists(self._identifier, settings)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\shared_system_client.py:30, in SharedSystemClient._create_system_if_not_exists(cls, identifier, settings)
#      27     cls._identifier_to_system[identifier] = new_system
#      29     new_system.instance(ProductTelemetryClient)
# ---> 30     new_system.instance(ServerAPI)
#      32     new_system.start()
#      33 else:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\config.py:397, in System.instance(self, type)
#     394     type = get_class(fqn, type)
#     396 if type not in self._instances:
# --> 397     impl = type(self)
#     398     self._instances[type] = impl
#     399     if self._running:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\api\segment.py:102, in SegmentAPI.__init__(self, system)
#     100 super().__init__(system)
#     101 self._settings = system.settings
# --> 102 self._sysdb = self.require(SysDB)
#     103 self._manager = self.require(SegmentManager)
#     104 self._quota = self.require(QuotaEnforcer)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\config.py:290, in Component.require(self, type)
#     287 def require(self, type: Type[T]) -> T:
#     288     """Get a Component instance of the given type, and register as a dependency of
#     289     that instance."""
# --> 290     inst = self._system.instance(type)
#     291     self._dependencies.add(inst)
#     292     return inst
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\config.py:397, in System.instance(self, type)
#     394     type = get_class(fqn, type)
#     396 if type not in self._instances:
# --> 397     impl = type(self)
#     398     self._instances[type] = impl
#     399     if self._running:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\db\impl\sqlite.py:86, in SqliteDB.__init__(self, system)
#      83     self._conn_pool = LockPool(self._db_file, is_uri=True)
#      84 else:
#      85     self._db_file = (
# ---> 86         self._settings.require("persist_directory") + "/chroma.sqlite3"
#      87     )
#      88     if not os.path.exists(self._db_file):
#      89         os.makedirs(os.path.dirname(self._db_file), exist_ok=True)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\chromadb\config.py:259, in Settings.require(self, key)
#     257 val = self[key]
#     258 if val is None:
# --> 259     raise ValueError(f"Missing required config value '{key}'")
#     260 return val
#
# ValueError: Missing required config value 'persist_directory'
